# %% [markdown]
# # Julia is fast

# %%
function matmul( A::Array{Float64,2}, B::Array{Float64,2})

    m, n  = size(A)
    p, q  = size(B)
    @assert n == p
    C = zeros(Float64,(m,q))
    for i = 1:m
        for j = 1:q
            C[i,j] = sum( A[i,:] .* B[:,j])
        end
    end
    C
end
# Out:
# matmul (generic function with 1 method)

# %%
@show A = rand(Float64,(4,5))
@show B = rand(Float64,(5,4))
# Out:
# A = rand(Float64, (4, 5)) = [0.241611 0.417429 0.228354 0.477761 0.953438; 0.612531 0.758927 0.21712 0.255127 0.617772; 0.568903 0.470955 0.650749 0.78061 0.921628; 0.823411 0.0580882 0.941221 0.266059 0.615409]
# B = rand(Float64, (5, 4)) = [0.160605 0.194814 0.432959 0.508427; 0.379324 0.594297 0.820769 0.585028; 0.206791 0.496093 0.615393 0.0512913; 0.565484 0.0244044 0.959953 0.532796; 0.170678 0.661504 0.327258 0.139451]
# 5×4 Array{Float64,2}:
#  0.160605  0.194814   0.432959  0.508427
#  0.379324  0.594297   0.820769  0.585028
#  0.206791  0.496093   0.615393  0.0512913
#  0.565484  0.0244044  0.959953  0.532796
#  0.170678  0.661504   0.327258  0.139451

# %%
matmul(A,B) == A * B
# Out:
# true

# %%
A * B
# Out:
# 4×4 Array{Float64,2}:
#  0.677263  1.05079  1.3584   0.766269
#  0.680863  1.09295  1.4688   0.988637
#  1.00331   1.34226  2.08428  1.14257
#  0.604403  1.07546  1.4402   0.728479

# %%
@code_llvm matmul(A,B)
# Out:
# ; Function matmul
# ; Location: In[1]:3
# define nonnull %jl_value_t addrspace(10)* @japi1_matmul_37047(%jl_value_t addrspace(10)*, %jl_value_t addrspace(10)**, i32) #0 {
# top:
#   %gcframe = alloca %jl_value_t addrspace(10)*, i32 6
#   %3 = bitcast %jl_value_t addrspace(10)** %gcframe to i8*
#   call void @llvm.memset.p0i8.i32(i8* %3, i8 0, i32 48, i32 0, i1 false)
#   %4 = alloca %jl_value_t addrspace(10)**, align 8
#   store volatile %jl_value_t addrspace(10)** %1, %jl_value_t addrspace(10)*** %4, align 8
#   %5 = alloca { { i64 } }, align 8
#   %6 = alloca { i64, { { i64 } } }, align 8
#   %7 = alloca { { i64 } }, align 8
#   %8 = alloca { { { i64 } }, i64 }, align 8
#   %9 = alloca [1 x { i64 }], align 8
#   %10 = alloca [1 x { i64 }], align 8
#   %11 = call %jl_value_t*** inttoptr (i64 4536557552 to %jl_value_t*** ()*)() #5
#   %12 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %gcframe, i32 0
#   %13 = bitcast %jl_value_t addrspace(10)** %12 to i64*
#   store i64 8, i64* %13
#   %14 = getelementptr %jl_value_t**, %jl_value_t*** %11, i32 0
#   %15 = load %jl_value_t**, %jl_value_t*** %14
#   %16 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %gcframe, i32 1
#   %17 = bitcast %jl_value_t addrspace(10)** %16 to %jl_value_t***
#   store %jl_value_t** %15, %jl_value_t*** %17
#   %18 = bitcast %jl_value_t*** %14 to %jl_value_t addrspace(10)***
#   store %jl_value_t addrspace(10)** %gcframe, %jl_value_t addrspace(10)*** %18
#   %19 = load %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %1, align 8
#   %20 = getelementptr inbounds %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %1, i64 1
#   %21 = load %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %20, align 8
# ; Function size; {
# ; Location: array.jl:156
#   %22 = addrspacecast %jl_value_t addrspace(10)* %19 to %jl_value_t addrspace(11)*
#   %23 = bitcast %jl_value_t addrspace(11)* %22 to %jl_value_t addrspace(10)* addrspace(11)*
#   %24 = getelementptr inbounds %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)* addrspace(11)* %23, i64 4
#   %25 = bitcast %jl_value_t addrspace(10)* addrspace(11)* %24 to i64 addrspace(11)*
#   %26 = load i64, i64 addrspace(11)* %25, align 8
# ;}
# ; Location: In[1]:4
# ; Function size; {
# ; Location: array.jl:156
#   %27 = addrspacecast %jl_value_t addrspace(10)* %21 to %jl_value_t addrspace(11)*
#   %28 = bitcast %jl_value_t addrspace(11)* %27 to %jl_value_t addrspace(10)* addrspace(11)*
#   %29 = getelementptr inbounds %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)* addrspace(11)* %28, i64 3
#   %30 = bitcast %jl_value_t addrspace(10)* addrspace(11)* %29 to i64 addrspace(11)*
#   %31 = load i64, i64 addrspace(11)* %30, align 8
# ;}
# ; Location: In[1]:5
# ; Function ==; {
# ; Location: promotion.jl:425
#   %32 = icmp eq i64 %26, %31
# ;}
#   br i1 %32, label %L7, label %L351
#
# L7:                                               ; preds = %top
# ; Location: In[1]:3
# ; Function size; {
# ; Location: array.jl:156
#   %33 = getelementptr inbounds %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)* addrspace(11)* %23, i64 3
#   %34 = bitcast %jl_value_t addrspace(10)* addrspace(11)* %33 to i64 addrspace(11)*
#   %35 = load i64, i64 addrspace(11)* %34, align 8
# ;}
# ; Location: In[1]:4
# ; Function size; {
# ; Location: array.jl:156
#   %36 = getelementptr inbounds %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)* addrspace(11)* %28, i64 4
#   %37 = bitcast %jl_value_t addrspace(10)* addrspace(11)* %36 to i64 addrspace(11)*
#   %38 = load i64, i64 addrspace(11)* %37, align 8
# ;}
# ; Location: In[1]:6
# ; Function zeros; {
# ; Location: array.jl:467
# ; Function Type; {
# ; Location: boot.jl:404
# ; Function Type; {
# ; Location: boot.jl:396
#   %39 = call %jl_value_t addrspace(10)* inttoptr (i64 4536398720 to %jl_value_t addrspace(10)* (%jl_value_t addrspace(10)*, i64, i64)*)(%jl_value_t addrspace(10)* addrspacecast (%jl_value_t* inttoptr (i64 4709455520 to %jl_value_t*) to %jl_value_t addrspace(10)*), i64 %35, i64 %38)
#   %40 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %gcframe, i32 2
#   store %jl_value_t addrspace(10)* %39, %jl_value_t addrspace(10)** %40
# ;}}
#   %41 = call nonnull %jl_value_t addrspace(10)* @"julia_fill!_37048"(%jl_value_t addrspace(10)* %39, double 0.000000e+00)
# ;}
# ; Location: In[1]:7
# ; Function Colon; {
# ; Location: range.jl:5
# ; Function Type; {
# ; Location: range.jl:255
# ; Function unitrange_last; {
# ; Location: range.jl:260
# ; Function >=; {
# ; Location: operators.jl:333
# ; Function <=; {
# ; Location: int.jl:428
#   %42 = icmp sgt i64 %35, 0
# ;}}}}}
#   br i1 %42, label %L17.L22_crit_edge, label %L350
#
# L17.L22_crit_edge:                                ; preds = %L7
#   %43 = icmp sgt i64 %38, 0
#   %44 = select i1 %43, i64 %38, i64 0
#   %45 = icmp sgt i64 %26, 0
#   %46 = select i1 %45, i64 %26, i64 0
#   %.sroa.066.0..sroa_idx = getelementptr inbounds { { i64 } }, { { i64 } }* %5, i64 0, i32 0, i32 0
#   %47 = getelementptr inbounds { i64, { { i64 } } }, { i64, { { i64 } } }* %6, i64 0, i32 0
#   %48 = getelementptr inbounds { i64, { { i64 } } }, { i64, { { i64 } } }* %6, i64 0, i32 1, i32 0, i32 0
#   %49 = addrspacecast { { i64 } }* %5 to { { i64 } } addrspace(11)*
#   %.sroa.065.0..sroa_idx = getelementptr inbounds { { i64 } }, { { i64 } }* %7, i64 0, i32 0, i32 0
#   %50 = getelementptr inbounds { { { i64 } }, i64 }, { { { i64 } }, i64 }* %8, i64 0, i32 0, i32 0, i32 0
#   %51 = getelementptr inbounds { { { i64 } }, i64 }, { { { i64 } }, i64 }* %8, i64 0, i32 1
#   %52 = addrspacecast { { i64 } }* %7 to { { i64 } } addrspace(11)*
#   %.sroa.055.0..sroa_idx56 = getelementptr inbounds [1 x { i64 }], [1 x { i64 }]* %9, i64 0, i64 0, i32 0
#   %53 = addrspacecast %jl_value_t addrspace(10)* %41 to %jl_value_t addrspace(11)*
#   %54 = bitcast %jl_value_t addrspace(11)* %53 to %jl_value_t addrspace(10)* addrspace(11)*
#   %55 = getelementptr inbounds %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)* addrspace(11)* %54, i64 3
#   %56 = bitcast %jl_value_t addrspace(10)* addrspace(11)* %55 to i64 addrspace(11)*
#   %57 = getelementptr inbounds %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)* addrspace(11)* %54, i64 4
#   %58 = bitcast %jl_value_t addrspace(10)* addrspace(11)* %57 to i64 addrspace(11)*
#   %59 = bitcast %jl_value_t addrspace(11)* %53 to double addrspace(13)* addrspace(11)*
#   br label %L22
#
# L22:                                              ; preds = %L17.L22_crit_edge, %L349
#   %.lcssa144180 = phi i64 [ undef, %L17.L22_crit_edge ], [ %.lcssa144181, %L349 ]
#   %value_phi3125.lcssa133178 = phi i64 [ undef, %L17.L22_crit_edge ], [ %value_phi3125.lcssa133179, %L349 ]
#   %.sroa.058.0.lcssa122165 = phi i64 [ undef, %L17.L22_crit_edge ], [ %.sroa.058.0.lcssa122164, %L349 ]
#   %value_phi883.lcssa113157 = phi i64 [ undef, %L17.L22_crit_edge ], [ %value_phi883.lcssa113156, %L349 ]
#   %60 = phi i64 [ undef, %L17.L22_crit_edge ], [ %321, %L349 ]
#   %value_phi3 = phi i64 [ 1, %L17.L22_crit_edge ], [ %323, %L349 ]
# ; Location: In[1]:8
#   br i1 %43, label %L31.L36_crit_edge, label %L339
#
# L31.L36_crit_edge:                                ; preds = %L22
# ; Location: In[1]:9
# ; Function getindex; {
# ; Location: abstractarray.jl:913
# ; Function to_indices; {
# ; Location: indices.jl:265
# ; Function to_indices; {
# ; Location: indices.jl:269
# ; Function to_indices; {
# ; Location: multidimensional.jl:573
# ; Function uncolon; {
# ; Location: multidimensional.jl:578
# ; Function Type; {
# ; Location: indices.jl:286
# ; Function Type; {
# ; Location: indices.jl:286
#   store i64 %46, i64* %.sroa.066.0..sroa_idx, align 8
# ;}}}}}}
# ; Function _getindex; {
# ; Location: multidimensional.jl:588
# ; Function checkbounds; {
# ; Location: abstractarray.jl:457
# ; Function checkbounds; {
# ; Location: abstractarray.jl:436
# ; Function checkbounds_indices; {
# ; Location: abstractarray.jl:483
# ; Function checkindex; {
# ; Location: abstractarray.jl:514
# ; Function <=; {
# ; Location: int.jl:428
#   %61 = icmp slt i64 %value_phi3, 1
#   %62 = icmp sgt i64 %value_phi3, %35
# ;}}}}
#   %63 = or i1 %61, %62
#   br i1 %63, label %L60, label %L63.lr.ph
#
# L63.lr.ph:                                        ; preds = %L31.L36_crit_edge
#   %64 = add i64 %value_phi3, -1
#   br label %L63
#
# L60:                                              ; preds = %L31.L36_crit_edge
# ;}
#   store i64 %value_phi3, i64* %47, align 8
#   store i64 %46, i64* %48, align 8
# ; Function checkbounds; {
# ; Location: abstractarray.jl:457
#   %65 = addrspacecast { i64, { { i64 } } }* %6 to { i64, { { i64 } } } addrspace(11)*
#   call void @julia_throw_boundserror_37055(%jl_value_t addrspace(10)* nonnull %19, { i64, { { i64 } } } addrspace(11)* nocapture readonly %65)
#   call void @llvm.trap()
#   unreachable
#
# L63:                                              ; preds = %L338, %L63.lr.ph
#   %value_phi883 = phi i64 [ 1, %L63.lr.ph ], [ %320, %L338 ]
#   %66 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %gcframe, i32 5
#   store %jl_value_t addrspace(10)* %41, %jl_value_t addrspace(10)** %66
# ;}
# ; Location: multidimensional.jl:589
#   %67 = call nonnull %jl_value_t addrspace(10)* @julia__unsafe_getindex_37049(%jl_value_t addrspace(10)* nonnull %19, i64 %value_phi3, { { i64 } } addrspace(11)* nocapture readonly %49)
# ;}
# ; Function to_indices; {
# ; Location: indices.jl:265
# ; Function to_indices; {
# ; Location: multidimensional.jl:573
# ; Function uncolon; {
# ; Location: multidimensional.jl:578
# ; Function Type; {
# ; Location: indices.jl:286
# ; Function Type; {
# ; Location: indices.jl:286
#   store i64 %46, i64* %.sroa.065.0..sroa_idx, align 8
# ;}}}}}
# ; Function _getindex; {
# ; Location: multidimensional.jl:588
# ; Function checkbounds; {
# ; Location: abstractarray.jl:457
# ; Function checkbounds; {
# ; Location: abstractarray.jl:436
# ; Function checkbounds_indices; {
# ; Location: abstractarray.jl:483
# ; Function checkbounds_indices; {
# ; Location: abstractarray.jl:483
# ; Function checkindex; {
# ; Location: abstractarray.jl:514
# ; Function <=; {
# ; Location: int.jl:428
#   %68 = icmp slt i64 %value_phi883, 1
#   %69 = icmp sgt i64 %value_phi883, %38
# ;}}}}}
#   %70 = or i1 %68, %69
#   br i1 %70, label %L89, label %L92
#
# L89:                                              ; preds = %L63
# ;}
#   store i64 %46, i64* %50, align 8
#   store i64 %value_phi883, i64* %51, align 8
# ; Function checkbounds; {
# ; Location: abstractarray.jl:457
#   %71 = addrspacecast { { { i64 } }, i64 }* %8 to { { { i64 } }, i64 } addrspace(11)*
#   call void @julia_throw_boundserror_37054(%jl_value_t addrspace(10)* nonnull %21, { { { i64 } }, i64 } addrspace(11)* nocapture readonly %71)
#   call void @llvm.trap()
#   unreachable
#
# L92:                                              ; preds = %L63
#   %72 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %gcframe, i32 2
#   store %jl_value_t addrspace(10)* %67, %jl_value_t addrspace(10)** %72
# ;}
# ; Location: multidimensional.jl:589
#   %73 = call nonnull %jl_value_t addrspace(10)* @julia__unsafe_getindex_37051(%jl_value_t addrspace(10)* nonnull %21, { { i64 } } addrspace(11)* nocapture readonly %52, i64 %value_phi883)
# ;}}
# ; Function materialize; {
# ; Location: broadcast.jl:724
# ; Function instantiate; {
# ; Location: broadcast.jl:266
# ; Function combine_axes; {
# ; Location: broadcast.jl:422
# ; Function broadcast_axes; {
# ; Location: broadcast.jl:206
# ; Function axes; {
# ; Location: abstractarray.jl:83
# ; Function size; {
# ; Location: array.jl:155
#   %74 = addrspacecast %jl_value_t addrspace(10)* %67 to %jl_value_t addrspace(11)*
#   %75 = bitcast %jl_value_t addrspace(11)* %74 to %jl_value_t addrspace(10)* addrspace(11)*
#   %76 = getelementptr inbounds %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)* addrspace(11)* %75, i64 3
#   %77 = bitcast %jl_value_t addrspace(10)* addrspace(11)* %76 to i64 addrspace(11)*
#   %78 = load i64, i64 addrspace(11)* %77, align 8
# ;}
# ; Function map; {
# ; Location: tuple.jl:162
# ; Function Type; {
# ; Location: range.jl:298
# ; Function Type; {
# ; Location: range.jl:289
# ; Function max; {
# ; Location: promotion.jl:436
#   %79 = icmp sgt i64 %78, 0
#   %80 = select i1 %79, i64 %78, i64 0
# ;}}}}}}
# ; Function combine_axes; {
# ; Location: broadcast.jl:423
# ; Function broadcast_axes; {
# ; Location: broadcast.jl:206
# ; Function axes; {
# ; Location: abstractarray.jl:83
# ; Function size; {
# ; Location: array.jl:155
#   %81 = addrspacecast %jl_value_t addrspace(10)* %73 to %jl_value_t addrspace(11)*
#   %82 = bitcast %jl_value_t addrspace(11)* %81 to %jl_value_t addrspace(10)* addrspace(11)*
#   %83 = getelementptr inbounds %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)* addrspace(11)* %82, i64 3
#   %84 = bitcast %jl_value_t addrspace(10)* addrspace(11)* %83 to i64 addrspace(11)*
#   %85 = load i64, i64 addrspace(11)* %84, align 8
# ;}
# ; Function map; {
# ; Location: tuple.jl:162
# ; Function Type; {
# ; Location: range.jl:298
# ; Function Type; {
# ; Location: range.jl:289
# ; Function max; {
# ; Location: promotion.jl:436
#   %86 = icmp sgt i64 %85, 0
#   %87 = select i1 %86, i64 %85, i64 0
# ;}}}}}}}
# ; Function broadcast_shape; {
# ; Location: broadcast.jl:427
# ; Function _bcs; {
# ; Location: broadcast.jl:433
# ; Function _bcs1; {
# ; Location: broadcast.jl:439
# ; Function _bcsm; {
# ; Location: broadcast.jl:441
# ; Function ==; {
# ; Location: range.jl:698
# ; Function ==; {
# ; Location: promotion.jl:425
#   %88 = icmp eq i64 %87, %80
# ;}}
# ; Function ==; {
# ; Location: promotion.jl:425
#   %89 = icmp eq i64 %80, 1
# ;}
#   %value_phi10.v = or i1 %89, %88
# ;}
#   br i1 %value_phi10.v, label %L124, label %L112
#
# L112:                                             ; preds = %L92
# ; Function _bcsm; {
# ; Location: broadcast.jl:441
# ; Function ==; {
# ; Location: promotion.jl:425
#   %90 = icmp eq i64 %87, 1
# ;}}
#   br i1 %90, label %L124, label %L121
#
# L121:                                             ; preds = %L112
# ; Function Type; {
# ; Location: array.jl:12
#   %91 = bitcast %jl_value_t*** %11 to i8*
#   %92 = call noalias nonnull %jl_value_t addrspace(10)* @jl_gc_pool_alloc(i8* %91, i32 1376, i32 16) #2
#   %93 = bitcast %jl_value_t addrspace(10)* %92 to %jl_value_t addrspace(10)* addrspace(10)*
#   %94 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)* addrspace(10)* %93, i64 -1
#   store %jl_value_t addrspace(10)* addrspacecast (%jl_value_t* inttoptr (i64 4716157488 to %jl_value_t*) to %jl_value_t addrspace(10)*), %jl_value_t addrspace(10)* addrspace(10)* %94
#   %95 = bitcast %jl_value_t addrspace(10)* %92 to %jl_value_t addrspace(10)* addrspace(10)*
#   store %jl_value_t addrspace(10)* addrspacecast (%jl_value_t* inttoptr (i64 4729676720 to %jl_value_t*) to %jl_value_t addrspace(10)*), %jl_value_t addrspace(10)* addrspace(10)* %95, align 8
# ;}
#   %96 = addrspacecast %jl_value_t addrspace(10)* %92 to %jl_value_t addrspace(12)*
#   %97 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %gcframe, i32 2
#   store %jl_value_t addrspace(10)* %92, %jl_value_t addrspace(10)** %97
#   call void @jl_throw(%jl_value_t addrspace(12)* %96)
#   unreachable
#
# L124:                                             ; preds = %L112, %L92
#   %.sroa.058.0 = phi i64 [ %87, %L92 ], [ %80, %L112 ]
#   %98 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %gcframe, i32 4
#   store %jl_value_t addrspace(10)* %73, %jl_value_t addrspace(10)** %98
# ;}}}}}
# ; Function copy; {
# ; Location: broadcast.jl:744
# ; Function similar; {
# ; Location: broadcast.jl:193
# ; Function similar; {
# ; Location: abstractarray.jl:625
# ; Function similar; {
# ; Location: abstractarray.jl:626
# ; Function Type; {
# ; Location: boot.jl:411
# ; Function Type; {
# ; Location: boot.jl:403
# ; Function Type; {
# ; Location: boot.jl:394
#   %99 = call %jl_value_t addrspace(10)* inttoptr (i64 4536398608 to %jl_value_t addrspace(10)* (%jl_value_t addrspace(10)*, i64)*)(%jl_value_t addrspace(10)* addrspacecast (%jl_value_t* inttoptr (i64 4709454944 to %jl_value_t*) to %jl_value_t addrspace(10)*), i64 %.sroa.058.0)
# ;}}}}}}
# ; Function copyto!; {
# ; Location: broadcast.jl:768
# ; Function copyto!; {
# ; Location: broadcast.jl:804
# ; Function axes; {
# ; Location: abstractarray.jl:83
# ; Function size; {
# ; Location: array.jl:155
#   %100 = addrspacecast %jl_value_t addrspace(10)* %99 to %jl_value_t addrspace(11)*
#   %101 = bitcast %jl_value_t addrspace(11)* %100 to %jl_value_t addrspace(10)* addrspace(11)*
#   %102 = getelementptr inbounds %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)* addrspace(11)* %101, i64 3
#   %103 = bitcast %jl_value_t addrspace(10)* addrspace(11)* %102 to i64 addrspace(11)*
#   %104 = load i64, i64 addrspace(11)* %103, align 8
# ;}
# ; Function map; {
# ; Location: tuple.jl:162
# ; Function Type; {
# ; Location: range.jl:298
# ; Function Type; {
# ; Location: range.jl:289
# ; Function max; {
# ; Location: promotion.jl:436
#   %105 = icmp sgt i64 %104, 0
#   %106 = select i1 %105, i64 %104, i64 0
# ;}}}}}
# ; Function ==; {
# ; Location: tuple.jl:280
# ; Function _eq; {
# ; Location: tuple.jl:284
# ; Function ==; {
# ; Location: range.jl:698
# ; Function ==; {
# ; Location: promotion.jl:425
#   %107 = icmp eq i64 %106, %.sroa.058.0
# ;}}}}
#   br i1 %107, label %L149, label %L269
#
# L149:                                             ; preds = %L124
# ; Location: broadcast.jl:812
# ; Function preprocess; {
# ; Location: broadcast.jl:795
# ; Function preprocess_args; {
# ; Location: broadcast.jl:798
# ; Function preprocess; {
# ; Location: broadcast.jl:796
# ; Function broadcast_unalias; {
# ; Location: broadcast.jl:789
#   %108 = icmp eq %jl_value_t addrspace(11)* %100, %74
#   br i1 %108, label %L165, label %L152
#
# L152:                                             ; preds = %L149
#   %109 = addrspacecast %jl_value_t addrspace(11)* %100 to %jl_value_t*
# ; Function unalias; {
# ; Location: abstractarray.jl:1087
# ; Function mightalias; {
# ; Location: abstractarray.jl:1121
# ; Function dataids; {
# ; Location: abstractarray.jl:1145
# ; Function pointer; {
# ; Location: abstractarray.jl:866
# ; Function unsafe_convert; {
# ; Location: pointer.jl:65
#   %110 = bitcast %jl_value_t* %109 to i64*
#   %111 = load i64, i64* %110, align 8
#   %112 = addrspacecast %jl_value_t addrspace(11)* %74 to %jl_value_t*
#   %113 = bitcast %jl_value_t* %112 to i64*
#   %114 = load i64, i64* %113, align 8
# ;}}}
# ; Function _isdisjoint; {
# ; Location: abstractarray.jl:1128
# ; Function !=; {
# ; Location: operators.jl:185
# ; Function ==; {
# ; Location: promotion.jl:425
#   %115 = icmp eq i64 %111, %114
# ;}}}}
#   br i1 %115, label %L160, label %L165
#
# L160:                                             ; preds = %L152
#   %116 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %gcframe, i32 3
#   store %jl_value_t addrspace(10)* %99, %jl_value_t addrspace(10)** %116
# ; Function unaliascopy; {
# ; Location: abstractarray.jl:1103
# ; Function copy; {
# ; Location: array.jl:299
#   %117 = call %jl_value_t addrspace(10)* inttoptr (i64 4536405472 to %jl_value_t addrspace(10)* (%jl_value_t addrspace(10)*)*)(%jl_value_t addrspace(10)* nonnull %67)
# ;}}
#   br label %L165
#
# L165:                                             ; preds = %L152, %L149, %L160
#   %value_phi18 = phi %jl_value_t addrspace(10)* [ %67, %L149 ], [ %117, %L160 ], [ %67, %L152 ]
# ;}}
# ; Function extrude; {
# ; Location: broadcast.jl:541
# ; Function newindexer; {
# ; Location: broadcast.jl:496
# ; Function broadcast_axes; {
# ; Location: broadcast.jl:206
# ; Function axes; {
# ; Location: abstractarray.jl:83
# ; Function size; {
# ; Location: array.jl:155
#   %118 = addrspacecast %jl_value_t addrspace(10)* %value_phi18 to %jl_value_t addrspace(11)*
#   %119 = bitcast %jl_value_t addrspace(11)* %118 to %jl_value_t addrspace(10)* addrspace(11)*
#   %120 = getelementptr inbounds %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)* addrspace(11)* %119, i64 3
#   %121 = bitcast %jl_value_t addrspace(10)* addrspace(11)* %120 to i64 addrspace(11)*
#   %122 = load i64, i64 addrspace(11)* %121, align 8
# ;}}}}}}
# ; Function preprocess_args; {
# ; Location: broadcast.jl:799
# ; Function preprocess; {
# ; Location: broadcast.jl:796
# ; Function broadcast_unalias; {
# ; Location: broadcast.jl:789
#   %123 = icmp eq %jl_value_t addrspace(11)* %100, %81
#   br i1 %123, label %L191, label %L178
#
# L178:                                             ; preds = %L165
#   %124 = addrspacecast %jl_value_t addrspace(11)* %100 to %jl_value_t*
# ; Function unalias; {
# ; Location: abstractarray.jl:1087
# ; Function mightalias; {
# ; Location: abstractarray.jl:1121
# ; Function dataids; {
# ; Location: abstractarray.jl:1145
# ; Function pointer; {
# ; Location: abstractarray.jl:866
# ; Function unsafe_convert; {
# ; Location: pointer.jl:65
#   %125 = bitcast %jl_value_t* %124 to i64*
#   %126 = load i64, i64* %125, align 8
#   %127 = addrspacecast %jl_value_t addrspace(11)* %81 to %jl_value_t*
#   %128 = bitcast %jl_value_t* %127 to i64*
#   %129 = load i64, i64* %128, align 8
# ;}}}
# ; Function _isdisjoint; {
# ; Location: abstractarray.jl:1128
# ; Function !=; {
# ; Location: operators.jl:185
# ; Function ==; {
# ; Location: promotion.jl:425
#   %130 = icmp eq i64 %126, %129
# ;}}}}
#   br i1 %130, label %L186, label %L191
#
# L186:                                             ; preds = %L178
#   %131 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %gcframe, i32 3
#   store %jl_value_t addrspace(10)* %99, %jl_value_t addrspace(10)** %131
#   %132 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %gcframe, i32 2
#   store %jl_value_t addrspace(10)* %value_phi18, %jl_value_t addrspace(10)** %132
# ; Function unaliascopy; {
# ; Location: abstractarray.jl:1103
# ; Function copy; {
# ; Location: array.jl:299
#   %133 = call %jl_value_t addrspace(10)* inttoptr (i64 4536405472 to %jl_value_t addrspace(10)* (%jl_value_t addrspace(10)*)*)(%jl_value_t addrspace(10)* nonnull %73)
# ;}}
#   br label %L191
#
# L191:                                             ; preds = %L178, %L165, %L186
#   %value_phi19 = phi %jl_value_t addrspace(10)* [ %73, %L165 ], [ %133, %L186 ], [ %73, %L178 ]
#   %134 = icmp eq i64 %.sroa.058.0, 0
#   %135 = bitcast %jl_value_t addrspace(11)* %100 to double addrspace(13)* addrspace(11)*
# ;}}}}}}
# ; Location: broadcast.jl:813
# ; Function macro expansion; {
# ; Location: simdloop.jl:66
#   br i1 %134, label %L279, label %L222.lr.ph
#
# L222.lr.ph:                                       ; preds = %L191
# ;}
# ; Location: broadcast.jl:812
# ; Function preprocess; {
# ; Location: broadcast.jl:795
# ; Function preprocess_args; {
# ; Location: broadcast.jl:798
# ; Function preprocess; {
# ; Location: broadcast.jl:796
# ; Function extrude; {
# ; Location: broadcast.jl:541
# ; Function newindexer; {
# ; Location: broadcast.jl:496
# ; Function shapeindexer; {
# ; Location: broadcast.jl:497
# ; Function _newindexer; {
# ; Location: broadcast.jl:502
# ; Function !=; {
# ; Location: operators.jl:185
# ; Function ==; {
# ; Location: promotion.jl:425
#   %136 = icmp eq i64 %122, 1
# ;}}}}}}}
# ; Function preprocess_args; {
# ; Location: broadcast.jl:799
# ; Function preprocess; {
# ; Location: broadcast.jl:796
# ; Function extrude; {
# ; Location: broadcast.jl:541
# ; Function newindexer; {
# ; Location: broadcast.jl:496
# ; Function broadcast_axes; {
# ; Location: broadcast.jl:206
# ; Function axes; {
# ; Location: abstractarray.jl:83
# ; Function size; {
# ; Location: array.jl:155
#   %137 = addrspacecast %jl_value_t addrspace(10)* %value_phi19 to %jl_value_t addrspace(11)*
#   %138 = bitcast %jl_value_t addrspace(11)* %137 to %jl_value_t addrspace(10)* addrspace(11)*
#   %139 = getelementptr inbounds %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)* addrspace(11)* %138, i64 3
#   %140 = bitcast %jl_value_t addrspace(10)* addrspace(11)* %139 to i64 addrspace(11)*
#   %141 = load i64, i64 addrspace(11)* %140, align 8
# ;}}}
# ; Function shapeindexer; {
# ; Location: broadcast.jl:497
# ; Function _newindexer; {
# ; Location: broadcast.jl:502
# ; Function !=; {
# ; Location: operators.jl:185
# ; Function ==; {
# ; Location: promotion.jl:425
#   %142 = icmp eq i64 %141, 1
#   %143 = bitcast %jl_value_t addrspace(11)* %118 to double addrspace(13)* addrspace(11)*
#   %144 = bitcast %jl_value_t addrspace(11)* %137 to double addrspace(13)* addrspace(11)*
#   %145 = load double addrspace(13)*, double addrspace(13)* addrspace(11)* %143, align 8
#   %bc = bitcast double addrspace(13)* %145 to i8 addrspace(13)*
#   %146 = bitcast double addrspace(13)* %145 to i8 addrspace(13)*
#   %147 = load double addrspace(13)*, double addrspace(13)* addrspace(11)* %144, align 8
#   %bc251 = bitcast double addrspace(13)* %147 to i8 addrspace(13)*
#   %148 = bitcast double addrspace(13)* %147 to i8 addrspace(13)*
#   %149 = load double addrspace(13)*, double addrspace(13)* addrspace(11)* %135, align 8
#   %150 = bitcast double addrspace(13)* %149 to i8 addrspace(13)*
# ;}}}}}}}}}}
# ; Location: broadcast.jl:813
# ; Function macro expansion; {
# ; Location: simdloop.jl:71
#   %min.iters.check = icmp ult i64 %.sroa.058.0, 16
#   br i1 %136, label %L222.lr.ph.split.us, label %L222.lr.ph.L222.lr.ph.split_crit_edge
#
# L222.lr.ph.L222.lr.ph.split_crit_edge:            ; preds = %L222.lr.ph
#   br i1 %142, label %L222.lr.ph.split.split.us, label %L222.lr.ph.split.L222.lr.ph.split.split_crit_edge
#
# L222.lr.ph.split.us:                              ; preds = %L222.lr.ph
#   br i1 %142, label %L222.lr.ph.split.us.split.us, label %L222.lr.ph.split.us.L222.lr.ph.split.us.split_crit_edge
#
# L222.lr.ph.split.us.L222.lr.ph.split.us.split_crit_edge: ; preds = %L222.lr.ph.split.us
#   br i1 %min.iters.check, label %scalar.ph260, label %vector.memcheck277
#
# vector.memcheck277:                               ; preds = %L222.lr.ph.split.us.L222.lr.ph.split.us.split_crit_edge
#   %scevgep263 = getelementptr double, double addrspace(13)* %149, i64 %.sroa.058.0
#   %uglygep265 = getelementptr i8, i8 addrspace(13)* %bc, i64 1
#   %scevgep266 = getelementptr double, double addrspace(13)* %147, i64 %.sroa.058.0
#   %bound0269 = icmp ugt i8 addrspace(13)* %uglygep265, %150
#   %bound1270 = icmp ult double addrspace(13)* %145, %scevgep263
#   %found.conflict271 = and i1 %bound0269, %bound1270
#   %bound0272 = icmp ult double addrspace(13)* %149, %scevgep266
#   %bound1273 = icmp ult double addrspace(13)* %147, %scevgep263
#   %found.conflict274 = and i1 %bound0272, %bound1273
#   %conflict.rdx275 = or i1 %found.conflict271, %found.conflict274
#   br i1 %conflict.rdx275, label %scalar.ph260, label %vector.ph278
#
# vector.ph278:                                     ; preds = %vector.memcheck277
#   %n.vec280 = and i64 %.sroa.058.0, 9223372036854775792
#   br label %vector.body258
#
# vector.body258:                                   ; preds = %vector.body258, %vector.ph278
# ; Location: simdloop.jl:73
# ; Function macro expansion; {
# ; Location: broadcast.jl:814
# ; Function +; {
# ; Location: int.jl:53
#   %index281 = phi i64 [ 0, %vector.ph278 ], [ %index.next282, %vector.body258 ]
# ;}
# ; Function getindex; {
# ; Location: broadcast.jl:507
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:546
# ; Function _getindex; {
# ; Location: broadcast.jl:570
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:540
# ; Function getindex; {
# ; Location: array.jl:731
#   %151 = load double, double addrspace(13)* %145, align 8
#   %152 = insertelement <4 x double> undef, double %151, i32 0
#   %153 = shufflevector <4 x double> %152, <4 x double> undef, <4 x i32> zeroinitializer
#   %154 = insertelement <4 x double> undef, double %151, i32 0
#   %155 = shufflevector <4 x double> %154, <4 x double> undef, <4 x i32> zeroinitializer
#   %156 = insertelement <4 x double> undef, double %151, i32 0
#   %157 = shufflevector <4 x double> %156, <4 x double> undef, <4 x i32> zeroinitializer
#   %158 = load double, double addrspace(13)* %145, align 8
# ;}}
# ; Function _getindex; {
# ; Location: broadcast.jl:571
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:540
# ; Function getindex; {
# ; Location: array.jl:731
#   %159 = insertelement <4 x double> undef, double %158, i32 0
#   %160 = shufflevector <4 x double> %159, <4 x double> undef, <4 x i32> zeroinitializer
#   %161 = getelementptr inbounds double, double addrspace(13)* %147, i64 %index281
#   %162 = bitcast double addrspace(13)* %161 to <4 x double> addrspace(13)*
#   %wide.load = load <4 x double>, <4 x double> addrspace(13)* %162, align 8
#   %163 = getelementptr double, double addrspace(13)* %161, i64 4
#   %164 = bitcast double addrspace(13)* %163 to <4 x double> addrspace(13)*
#   %wide.load291 = load <4 x double>, <4 x double> addrspace(13)* %164, align 8
#   %165 = getelementptr double, double addrspace(13)* %161, i64 8
#   %166 = bitcast double addrspace(13)* %165 to <4 x double> addrspace(13)*
#   %wide.load292 = load <4 x double>, <4 x double> addrspace(13)* %166, align 8
#   %167 = getelementptr double, double addrspace(13)* %161, i64 12
#   %168 = bitcast double addrspace(13)* %167 to <4 x double> addrspace(13)*
#   %wide.load293 = load <4 x double>, <4 x double> addrspace(13)* %168, align 8
# ;}}}}}}
# ; Function +; {
# ; Location: int.jl:53
#   %169 = fmul <4 x double> %153, %wide.load
#   %170 = fmul <4 x double> %155, %wide.load291
#   %171 = fmul <4 x double> %157, %wide.load292
#   %172 = fmul <4 x double> %160, %wide.load293
# ;}
# ; Function setindex!; {
# ; Location: array.jl:769
#   %173 = getelementptr inbounds double, double addrspace(13)* %149, i64 %index281
#   %174 = bitcast double addrspace(13)* %173 to <4 x double> addrspace(13)*
#   store <4 x double> %169, <4 x double> addrspace(13)* %174, align 8
#   %175 = getelementptr double, double addrspace(13)* %173, i64 4
#   %176 = bitcast double addrspace(13)* %175 to <4 x double> addrspace(13)*
#   store <4 x double> %170, <4 x double> addrspace(13)* %176, align 8
#   %177 = getelementptr double, double addrspace(13)* %173, i64 8
#   %178 = bitcast double addrspace(13)* %177 to <4 x double> addrspace(13)*
#   store <4 x double> %171, <4 x double> addrspace(13)* %178, align 8
#   %179 = getelementptr double, double addrspace(13)* %173, i64 12
#   %180 = bitcast double addrspace(13)* %179 to <4 x double> addrspace(13)*
#   store <4 x double> %172, <4 x double> addrspace(13)* %180, align 8
# ;}
# ; Function +; {
# ; Location: int.jl:53
#   %index.next282 = add i64 %index281, 16
#   %181 = icmp eq i64 %index.next282, %n.vec280
#   br i1 %181, label %middle.block259, label %vector.body258
#
# middle.block259:                                  ; preds = %vector.body258
#   %cmp.n284 = icmp eq i64 %.sroa.058.0, %n.vec280
# ;}}
# ; Location: simdloop.jl:71
#   br i1 %cmp.n284, label %L279, label %scalar.ph260
#
# scalar.ph260:                                     ; preds = %middle.block259, %vector.memcheck277, %L222.lr.ph.split.us.L222.lr.ph.split.us.split_crit_edge
#   %bc.resume.val283 = phi i64 [ %n.vec280, %middle.block259 ], [ 0, %L222.lr.ph.split.us.L222.lr.ph.split.us.split_crit_edge ], [ 0, %vector.memcheck277 ]
#   br label %L222.us
#
# L222.lr.ph.split.us.split.us:                     ; preds = %L222.lr.ph.split.us
#   br i1 %min.iters.check, label %scalar.ph, label %vector.memcheck
#
# vector.memcheck:                                  ; preds = %L222.lr.ph.split.us.split.us
#   %scevgep = getelementptr double, double addrspace(13)* %149, i64 %.sroa.058.0
#   %uglygep = getelementptr i8, i8 addrspace(13)* %146, i64 1
#   %uglygep250 = getelementptr i8, i8 addrspace(13)* %148, i64 1
#   %bound0 = icmp ugt i8 addrspace(13)* %uglygep, %150
#   %bound1 = icmp ult double addrspace(13)* %145, %scevgep
#   %found.conflict = and i1 %bound0, %bound1
#   %bound0252 = icmp ugt i8 addrspace(13)* %uglygep250, %150
#   %bound1253 = icmp ult double addrspace(13)* %147, %scevgep
#   %found.conflict254 = and i1 %bound0252, %bound1253
#   %conflict.rdx = or i1 %found.conflict, %found.conflict254
#   br i1 %conflict.rdx, label %scalar.ph, label %vector.ph
#
# vector.ph:                                        ; preds = %vector.memcheck
#   %n.vec = and i64 %.sroa.058.0, 9223372036854775792
#   br label %vector.body
#
# vector.body:                                      ; preds = %vector.body, %vector.ph
# ; Location: simdloop.jl:73
# ; Function macro expansion; {
# ; Location: broadcast.jl:814
# ; Function +; {
# ; Location: int.jl:53
#   %index = phi i64 [ 0, %vector.ph ], [ %index.next, %vector.body ]
# ;}
# ; Function getindex; {
# ; Location: broadcast.jl:507
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:546
# ; Function _getindex; {
# ; Location: broadcast.jl:570
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:540
# ; Function getindex; {
# ; Location: array.jl:731
#   %182 = load double, double addrspace(13)* %145, align 8
#   %183 = insertelement <4 x double> undef, double %182, i32 0
#   %184 = insertelement <4 x double> undef, double %182, i32 0
#   %185 = insertelement <4 x double> undef, double %182, i32 0
# ;}}
# ; Function _getindex; {
# ; Location: broadcast.jl:571
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:540
# ; Function getindex; {
# ; Location: array.jl:731
#   %186 = insertelement <4 x double> undef, double %182, i32 0
#   %187 = load double, double addrspace(13)* %147, align 8
#   %188 = insertelement <4 x double> undef, double %187, i32 0
#   %189 = insertelement <4 x double> undef, double %187, i32 0
#   %190 = insertelement <4 x double> undef, double %187, i32 0
# ;}}}}}}
# ; Function +; {
# ; Location: int.jl:53
#   %191 = insertelement <4 x double> undef, double %187, i32 0
#   %192 = fmul <4 x double> %183, %188
#   %193 = shufflevector <4 x double> %192, <4 x double> undef, <4 x i32> zeroinitializer
#   %194 = fmul <4 x double> %184, %189
#   %195 = shufflevector <4 x double> %194, <4 x double> undef, <4 x i32> zeroinitializer
#   %196 = fmul <4 x double> %185, %190
#   %197 = shufflevector <4 x double> %196, <4 x double> undef, <4 x i32> zeroinitializer
#   %198 = fmul <4 x double> %186, %191
#   %199 = shufflevector <4 x double> %198, <4 x double> undef, <4 x i32> zeroinitializer
# ;}
# ; Function setindex!; {
# ; Location: array.jl:769
#   %200 = getelementptr inbounds double, double addrspace(13)* %149, i64 %index
#   %201 = bitcast double addrspace(13)* %200 to <4 x double> addrspace(13)*
#   store <4 x double> %193, <4 x double> addrspace(13)* %201, align 8
#   %202 = getelementptr double, double addrspace(13)* %200, i64 4
#   %203 = bitcast double addrspace(13)* %202 to <4 x double> addrspace(13)*
#   store <4 x double> %195, <4 x double> addrspace(13)* %203, align 8
#   %204 = getelementptr double, double addrspace(13)* %200, i64 8
#   %205 = bitcast double addrspace(13)* %204 to <4 x double> addrspace(13)*
#   store <4 x double> %197, <4 x double> addrspace(13)* %205, align 8
#   %206 = getelementptr double, double addrspace(13)* %200, i64 12
#   %207 = bitcast double addrspace(13)* %206 to <4 x double> addrspace(13)*
#   store <4 x double> %199, <4 x double> addrspace(13)* %207, align 8
# ;}
# ; Function +; {
# ; Location: int.jl:53
#   %index.next = add i64 %index, 16
#   %208 = icmp eq i64 %index.next, %n.vec
#   br i1 %208, label %middle.block, label %vector.body
#
# middle.block:                                     ; preds = %vector.body
#   %cmp.n = icmp eq i64 %.sroa.058.0, %n.vec
# ;}}
# ; Location: simdloop.jl:71
#   br i1 %cmp.n, label %L279, label %scalar.ph
#
# scalar.ph:                                        ; preds = %middle.block, %vector.memcheck, %L222.lr.ph.split.us.split.us
#   %bc.resume.val = phi i64 [ %n.vec, %middle.block ], [ 0, %L222.lr.ph.split.us.split.us ], [ 0, %vector.memcheck ]
#   br label %L222.us.us
#
# L222.us.us:                                       ; preds = %L222.us.us, %scalar.ph
#   %value_phi2380.us.us = phi i64 [ %bc.resume.val, %scalar.ph ], [ %213, %L222.us.us ]
# ; Location: simdloop.jl:73
# ; Function macro expansion; {
# ; Location: broadcast.jl:814
# ; Function getindex; {
# ; Location: broadcast.jl:507
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:546
# ; Function _getindex; {
# ; Location: broadcast.jl:570
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:540
# ; Function getindex; {
# ; Location: array.jl:731
#   %209 = load double, double addrspace(13)* %145, align 8
# ;}}
# ; Function _getindex; {
# ; Location: broadcast.jl:571
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:540
# ; Function getindex; {
# ; Location: array.jl:731
#   %210 = load double, double addrspace(13)* %147, align 8
# ;}}}}
# ; Location: broadcast.jl:547
# ; Function _broadcast_getindex_evalf; {
# ; Location: broadcast.jl:574
# ; Function *; {
# ; Location: float.jl:399
#   %211 = fmul double %209, %210
# ;}}}}
# ; Function setindex!; {
# ; Location: array.jl:769
#   %212 = getelementptr inbounds double, double addrspace(13)* %149, i64 %value_phi2380.us.us
#   store double %211, double addrspace(13)* %212, align 8
# ;}
# ; Function +; {
# ; Location: int.jl:53
#   %213 = add nuw nsw i64 %value_phi2380.us.us, 1
# ;}}
# ; Location: simdloop.jl:71
# ; Function <; {
# ; Location: int.jl:49
#   %214 = icmp ult i64 %213, %.sroa.058.0
# ;}
#   br i1 %214, label %L222.us.us, label %L279
#
# L222.us:                                          ; preds = %L222.us, %scalar.ph260
#   %value_phi2380.us = phi i64 [ %bc.resume.val283, %scalar.ph260 ], [ %220, %L222.us ]
# ; Location: simdloop.jl:73
# ; Function macro expansion; {
# ; Location: broadcast.jl:814
# ; Function getindex; {
# ; Location: broadcast.jl:507
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:546
# ; Function _getindex; {
# ; Location: broadcast.jl:570
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:540
# ; Function getindex; {
# ; Location: array.jl:731
#   %215 = load double, double addrspace(13)* %145, align 8
# ;}}
# ; Function _getindex; {
# ; Location: broadcast.jl:571
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:540
# ; Function getindex; {
# ; Location: array.jl:731
#   %216 = getelementptr inbounds double, double addrspace(13)* %147, i64 %value_phi2380.us
#   %217 = load double, double addrspace(13)* %216, align 8
# ;}}}}
# ; Location: broadcast.jl:547
# ; Function _broadcast_getindex_evalf; {
# ; Location: broadcast.jl:574
# ; Function *; {
# ; Location: float.jl:399
#   %218 = fmul double %215, %217
# ;}}}}
# ; Function setindex!; {
# ; Location: array.jl:769
#   %219 = getelementptr inbounds double, double addrspace(13)* %149, i64 %value_phi2380.us
#   store double %218, double addrspace(13)* %219, align 8
# ;}
# ; Function +; {
# ; Location: int.jl:53
#   %220 = add nuw nsw i64 %value_phi2380.us, 1
# ;}}
# ; Location: simdloop.jl:71
# ; Function <; {
# ; Location: int.jl:49
#   %221 = icmp ult i64 %220, %.sroa.058.0
# ;}
#   br i1 %221, label %L222.us, label %L279
#
# L222.lr.ph.split.L222.lr.ph.split.split_crit_edge: ; preds = %L222.lr.ph.L222.lr.ph.split_crit_edge
#   br i1 %min.iters.check, label %scalar.ph333, label %vector.memcheck350
#
# vector.memcheck350:                               ; preds = %L222.lr.ph.split.L222.lr.ph.split.split_crit_edge
#   %scevgep336 = getelementptr double, double addrspace(13)* %149, i64 %.sroa.058.0
#   %scevgep338 = getelementptr double, double addrspace(13)* %145, i64 %.sroa.058.0
#   %scevgep340 = getelementptr double, double addrspace(13)* %147, i64 %.sroa.058.0
#   %bound0342 = icmp ult double addrspace(13)* %149, %scevgep338
#   %bound1343 = icmp ult double addrspace(13)* %145, %scevgep336
#   %found.conflict344 = and i1 %bound0342, %bound1343
#   %bound0345 = icmp ult double addrspace(13)* %149, %scevgep340
#   %bound1346 = icmp ult double addrspace(13)* %147, %scevgep336
#   %found.conflict347 = and i1 %bound0345, %bound1346
#   %conflict.rdx348 = or i1 %found.conflict344, %found.conflict347
#   br i1 %conflict.rdx348, label %scalar.ph333, label %vector.ph351
#
# vector.ph351:                                     ; preds = %vector.memcheck350
#   %n.vec353 = and i64 %.sroa.058.0, 9223372036854775792
#   br label %vector.body331
#
# vector.body331:                                   ; preds = %vector.body331, %vector.ph351
# ; Location: simdloop.jl:73
# ; Function macro expansion; {
# ; Location: broadcast.jl:814
# ; Function +; {
# ; Location: int.jl:53
#   %index354 = phi i64 [ 0, %vector.ph351 ], [ %index.next355, %vector.body331 ]
# ;}
# ; Function getindex; {
# ; Location: broadcast.jl:507
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:546
# ; Function _getindex; {
# ; Location: broadcast.jl:570
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:540
# ; Function getindex; {
# ; Location: array.jl:731
#   %222 = getelementptr inbounds double, double addrspace(13)* %145, i64 %index354
#   %223 = bitcast double addrspace(13)* %222 to <4 x double> addrspace(13)*
#   %wide.load364 = load <4 x double>, <4 x double> addrspace(13)* %223, align 8
#   %224 = getelementptr double, double addrspace(13)* %222, i64 4
#   %225 = bitcast double addrspace(13)* %224 to <4 x double> addrspace(13)*
#   %wide.load365 = load <4 x double>, <4 x double> addrspace(13)* %225, align 8
#   %226 = getelementptr double, double addrspace(13)* %222, i64 8
#   %227 = bitcast double addrspace(13)* %226 to <4 x double> addrspace(13)*
#   %wide.load366 = load <4 x double>, <4 x double> addrspace(13)* %227, align 8
#   %228 = getelementptr double, double addrspace(13)* %222, i64 12
#   %229 = bitcast double addrspace(13)* %228 to <4 x double> addrspace(13)*
#   %wide.load367 = load <4 x double>, <4 x double> addrspace(13)* %229, align 8
# ;}}
# ; Function _getindex; {
# ; Location: broadcast.jl:571
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:540
# ; Function getindex; {
# ; Location: array.jl:731
#   %230 = getelementptr inbounds double, double addrspace(13)* %147, i64 %index354
#   %231 = bitcast double addrspace(13)* %230 to <4 x double> addrspace(13)*
#   %wide.load368 = load <4 x double>, <4 x double> addrspace(13)* %231, align 8
#   %232 = getelementptr double, double addrspace(13)* %230, i64 4
#   %233 = bitcast double addrspace(13)* %232 to <4 x double> addrspace(13)*
#   %wide.load369 = load <4 x double>, <4 x double> addrspace(13)* %233, align 8
#   %234 = getelementptr double, double addrspace(13)* %230, i64 8
#   %235 = bitcast double addrspace(13)* %234 to <4 x double> addrspace(13)*
#   %wide.load370 = load <4 x double>, <4 x double> addrspace(13)* %235, align 8
#   %236 = getelementptr double, double addrspace(13)* %230, i64 12
#   %237 = bitcast double addrspace(13)* %236 to <4 x double> addrspace(13)*
#   %wide.load371 = load <4 x double>, <4 x double> addrspace(13)* %237, align 8
# ;}}}}
# ; Location: broadcast.jl:547
# ; Function _broadcast_getindex_evalf; {
# ; Location: broadcast.jl:574
# ; Function *; {
# ; Location: float.jl:399
#   %238 = fmul <4 x double> %wide.load364, %wide.load368
#   %239 = fmul <4 x double> %wide.load365, %wide.load369
#   %240 = fmul <4 x double> %wide.load366, %wide.load370
#   %241 = fmul <4 x double> %wide.load367, %wide.load371
# ;}}}}
# ; Function setindex!; {
# ; Location: array.jl:769
#   %242 = getelementptr inbounds double, double addrspace(13)* %149, i64 %index354
#   %243 = bitcast double addrspace(13)* %242 to <4 x double> addrspace(13)*
#   store <4 x double> %238, <4 x double> addrspace(13)* %243, align 8
#   %244 = getelementptr double, double addrspace(13)* %242, i64 4
#   %245 = bitcast double addrspace(13)* %244 to <4 x double> addrspace(13)*
#   store <4 x double> %239, <4 x double> addrspace(13)* %245, align 8
#   %246 = getelementptr double, double addrspace(13)* %242, i64 8
#   %247 = bitcast double addrspace(13)* %246 to <4 x double> addrspace(13)*
#   store <4 x double> %240, <4 x double> addrspace(13)* %247, align 8
#   %248 = getelementptr double, double addrspace(13)* %242, i64 12
#   %249 = bitcast double addrspace(13)* %248 to <4 x double> addrspace(13)*
#   store <4 x double> %241, <4 x double> addrspace(13)* %249, align 8
# ;}
# ; Function +; {
# ; Location: int.jl:53
#   %index.next355 = add i64 %index354, 16
#   %250 = icmp eq i64 %index.next355, %n.vec353
#   br i1 %250, label %middle.block332, label %vector.body331
#
# middle.block332:                                  ; preds = %vector.body331
#   %cmp.n357 = icmp eq i64 %.sroa.058.0, %n.vec353
# ;}}
# ; Location: simdloop.jl:71
#   br i1 %cmp.n357, label %L279, label %scalar.ph333
#
# scalar.ph333:                                     ; preds = %middle.block332, %vector.memcheck350, %L222.lr.ph.split.L222.lr.ph.split.split_crit_edge
#   %bc.resume.val356 = phi i64 [ %n.vec353, %middle.block332 ], [ 0, %L222.lr.ph.split.L222.lr.ph.split.split_crit_edge ], [ 0, %vector.memcheck350 ]
#   br label %L222
#
# L222.lr.ph.split.split.us:                        ; preds = %L222.lr.ph.L222.lr.ph.split_crit_edge
#   br i1 %min.iters.check, label %scalar.ph296, label %vector.memcheck313
#
# vector.memcheck313:                               ; preds = %L222.lr.ph.split.split.us
#   %scevgep299 = getelementptr double, double addrspace(13)* %149, i64 %.sroa.058.0
#   %scevgep301 = getelementptr double, double addrspace(13)* %145, i64 %.sroa.058.0
#   %uglygep303 = getelementptr i8, i8 addrspace(13)* %bc251, i64 1
#   %bound0304 = icmp ult double addrspace(13)* %149, %scevgep301
#   %bound1305 = icmp ult double addrspace(13)* %145, %scevgep299
#   %found.conflict306 = and i1 %bound0304, %bound1305
#   %bound0308 = icmp ugt i8 addrspace(13)* %uglygep303, %150
#   %bound1309 = icmp ult double addrspace(13)* %147, %scevgep299
#   %found.conflict310 = and i1 %bound0308, %bound1309
#   %conflict.rdx311 = or i1 %found.conflict306, %found.conflict310
#   br i1 %conflict.rdx311, label %scalar.ph296, label %vector.ph314
#
# vector.ph314:                                     ; preds = %vector.memcheck313
#   %n.vec316 = and i64 %.sroa.058.0, 9223372036854775792
#   br label %vector.body294
#
# vector.body294:                                   ; preds = %vector.body294, %vector.ph314
# ; Location: simdloop.jl:73
# ; Function macro expansion; {
# ; Location: broadcast.jl:814
# ; Function +; {
# ; Location: int.jl:53
#   %index317 = phi i64 [ 0, %vector.ph314 ], [ %index.next318, %vector.body294 ]
# ;}
# ; Function getindex; {
# ; Location: broadcast.jl:507
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:546
# ; Function _getindex; {
# ; Location: broadcast.jl:570
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:540
# ; Function getindex; {
# ; Location: array.jl:731
#   %251 = getelementptr inbounds double, double addrspace(13)* %145, i64 %index317
#   %252 = bitcast double addrspace(13)* %251 to <4 x double> addrspace(13)*
#   %wide.load327 = load <4 x double>, <4 x double> addrspace(13)* %252, align 8
#   %253 = getelementptr double, double addrspace(13)* %251, i64 4
#   %254 = bitcast double addrspace(13)* %253 to <4 x double> addrspace(13)*
#   %wide.load328 = load <4 x double>, <4 x double> addrspace(13)* %254, align 8
#   %255 = getelementptr double, double addrspace(13)* %251, i64 8
#   %256 = bitcast double addrspace(13)* %255 to <4 x double> addrspace(13)*
#   %wide.load329 = load <4 x double>, <4 x double> addrspace(13)* %256, align 8
#   %257 = getelementptr double, double addrspace(13)* %251, i64 12
#   %258 = bitcast double addrspace(13)* %257 to <4 x double> addrspace(13)*
#   %wide.load330 = load <4 x double>, <4 x double> addrspace(13)* %258, align 8
# ;}}
# ; Function _getindex; {
# ; Location: broadcast.jl:571
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:540
# ; Function getindex; {
# ; Location: array.jl:731
#   %259 = load double, double addrspace(13)* %147, align 8
#   %260 = insertelement <4 x double> undef, double %259, i32 0
#   %261 = shufflevector <4 x double> %260, <4 x double> undef, <4 x i32> zeroinitializer
#   %262 = insertelement <4 x double> undef, double %259, i32 0
#   %263 = shufflevector <4 x double> %262, <4 x double> undef, <4 x i32> zeroinitializer
#   %264 = insertelement <4 x double> undef, double %259, i32 0
#   %265 = shufflevector <4 x double> %264, <4 x double> undef, <4 x i32> zeroinitializer
#   %266 = load double, double addrspace(13)* %147, align 8
# ;}}}}}}
# ; Function +; {
# ; Location: int.jl:53
#   %267 = insertelement <4 x double> undef, double %266, i32 0
#   %268 = shufflevector <4 x double> %267, <4 x double> undef, <4 x i32> zeroinitializer
#   %269 = fmul <4 x double> %wide.load327, %261
#   %270 = fmul <4 x double> %wide.load328, %263
#   %271 = fmul <4 x double> %wide.load329, %265
#   %272 = fmul <4 x double> %wide.load330, %268
# ;}
# ; Function setindex!; {
# ; Location: array.jl:769
#   %273 = getelementptr inbounds double, double addrspace(13)* %149, i64 %index317
#   %274 = bitcast double addrspace(13)* %273 to <4 x double> addrspace(13)*
#   store <4 x double> %269, <4 x double> addrspace(13)* %274, align 8
#   %275 = getelementptr double, double addrspace(13)* %273, i64 4
#   %276 = bitcast double addrspace(13)* %275 to <4 x double> addrspace(13)*
#   store <4 x double> %270, <4 x double> addrspace(13)* %276, align 8
#   %277 = getelementptr double, double addrspace(13)* %273, i64 8
#   %278 = bitcast double addrspace(13)* %277 to <4 x double> addrspace(13)*
#   store <4 x double> %271, <4 x double> addrspace(13)* %278, align 8
#   %279 = getelementptr double, double addrspace(13)* %273, i64 12
#   %280 = bitcast double addrspace(13)* %279 to <4 x double> addrspace(13)*
#   store <4 x double> %272, <4 x double> addrspace(13)* %280, align 8
# ;}
# ; Function +; {
# ; Location: int.jl:53
#   %index.next318 = add i64 %index317, 16
#   %281 = icmp eq i64 %index.next318, %n.vec316
#   br i1 %281, label %middle.block295, label %vector.body294
#
# middle.block295:                                  ; preds = %vector.body294
#   %cmp.n320 = icmp eq i64 %.sroa.058.0, %n.vec316
# ;}}
# ; Location: simdloop.jl:71
#   br i1 %cmp.n320, label %L279, label %scalar.ph296
#
# scalar.ph296:                                     ; preds = %middle.block295, %vector.memcheck313, %L222.lr.ph.split.split.us
#   %bc.resume.val319 = phi i64 [ %n.vec316, %middle.block295 ], [ 0, %L222.lr.ph.split.split.us ], [ 0, %vector.memcheck313 ]
#   br label %L222.us84
#
# L222.us84:                                        ; preds = %L222.us84, %scalar.ph296
#   %value_phi2380.us85 = phi i64 [ %bc.resume.val319, %scalar.ph296 ], [ %287, %L222.us84 ]
# ; Location: simdloop.jl:73
# ; Function macro expansion; {
# ; Location: broadcast.jl:814
# ; Function getindex; {
# ; Location: broadcast.jl:507
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:546
# ; Function _getindex; {
# ; Location: broadcast.jl:570
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:540
# ; Function getindex; {
# ; Location: array.jl:731
#   %282 = getelementptr inbounds double, double addrspace(13)* %145, i64 %value_phi2380.us85
#   %283 = load double, double addrspace(13)* %282, align 8
# ;}}
# ; Function _getindex; {
# ; Location: broadcast.jl:571
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:540
# ; Function getindex; {
# ; Location: array.jl:731
#   %284 = load double, double addrspace(13)* %147, align 8
# ;}}}}
# ; Location: broadcast.jl:547
# ; Function _broadcast_getindex_evalf; {
# ; Location: broadcast.jl:574
# ; Function *; {
# ; Location: float.jl:399
#   %285 = fmul double %283, %284
# ;}}}}
# ; Function setindex!; {
# ; Location: array.jl:769
#   %286 = getelementptr inbounds double, double addrspace(13)* %149, i64 %value_phi2380.us85
#   store double %285, double addrspace(13)* %286, align 8
# ;}
# ; Function +; {
# ; Location: int.jl:53
#   %287 = add nuw nsw i64 %value_phi2380.us85, 1
# ;}}
# ; Location: simdloop.jl:71
# ; Function <; {
# ; Location: int.jl:49
#   %288 = icmp ult i64 %287, %.sroa.058.0
# ;}
#   br i1 %288, label %L222.us84, label %L279
#
# L222:                                             ; preds = %scalar.ph333, %L222
#   %value_phi2380 = phi i64 [ %bc.resume.val356, %scalar.ph333 ], [ %295, %L222 ]
# ; Location: simdloop.jl:73
# ; Function macro expansion; {
# ; Location: broadcast.jl:814
# ; Function getindex; {
# ; Location: broadcast.jl:507
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:546
# ; Function _getindex; {
# ; Location: broadcast.jl:570
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:540
# ; Function getindex; {
# ; Location: array.jl:731
#   %289 = getelementptr inbounds double, double addrspace(13)* %145, i64 %value_phi2380
#   %290 = load double, double addrspace(13)* %289, align 8
# ;}}
# ; Function _getindex; {
# ; Location: broadcast.jl:571
# ; Function _broadcast_getindex; {
# ; Location: broadcast.jl:540
# ; Function getindex; {
# ; Location: array.jl:731
#   %291 = getelementptr inbounds double, double addrspace(13)* %147, i64 %value_phi2380
#   %292 = load double, double addrspace(13)* %291, align 8
# ;}}}}
# ; Location: broadcast.jl:547
# ; Function _broadcast_getindex_evalf; {
# ; Location: broadcast.jl:574
# ; Function *; {
# ; Location: float.jl:399
#   %293 = fmul double %290, %292
# ;}}}}
# ; Function setindex!; {
# ; Location: array.jl:769
#   %294 = getelementptr inbounds double, double addrspace(13)* %149, i64 %value_phi2380
#   store double %293, double addrspace(13)* %294, align 8
# ;}
# ; Function +; {
# ; Location: int.jl:53
#   %295 = add nuw nsw i64 %value_phi2380, 1
# ;}}
# ; Location: simdloop.jl:71
# ; Function <; {
# ; Location: int.jl:49
#   %296 = icmp ult i64 %295, %.sroa.058.0
# ;}
#   br i1 %296, label %L222, label %L279
#
# L269:                                             ; preds = %L124
# ;}}}}
# ; Function instantiate; {
# ; Location: broadcast.jl:266
# ; Function combine_axes; {
# ; Location: broadcast.jl:422
# ; Function broadcast_shape; {
# ; Location: broadcast.jl:427
# ; Function _bcs; {
# ; Location: broadcast.jl:433
#   store i64 %.sroa.058.0, i64* %.sroa.055.0..sroa_idx56, align 8
# ;}}}}
# ; Function copy; {
# ; Location: broadcast.jl:744
# ; Function copyto!; {
# ; Location: broadcast.jl:768
# ; Function copyto!; {
# ; Location: broadcast.jl:804
# ; Function axes; {
# ; Location: abstractarray.jl:83
# ; Function map; {
# ; Location: tuple.jl:162
#   %.sroa.0.0..sroa_idx = getelementptr inbounds [1 x { i64 }], [1 x { i64 }]* %10, i64 0, i64 0, i32 0
#   store i64 %106, i64* %.sroa.0.0..sroa_idx, align 8
# ;}}
#   %297 = addrspacecast [1 x { i64 }]* %10 to [1 x { i64 }] addrspace(11)*
#   %298 = addrspacecast [1 x { i64 }]* %9 to [1 x { i64 }] addrspace(11)*
#   call void @julia_throwdm_26470([1 x { i64 }] addrspace(11)* nocapture readonly %297, [1 x { i64 }] addrspace(11)* nocapture readonly %298)
#   call void @llvm.trap()
#   unreachable
#
# L279:                                             ; preds = %L222, %middle.block332, %L222.us84, %middle.block295, %L222.us, %middle.block259, %L222.us.us, %middle.block, %L191
# ;}}}}
# ; Function sum; {
# ; Location: reducedim.jl:645
# ; Function #sum#544; {
# ; Location: reducedim.jl:645
# ; Function _sum; {
# ; Location: reducedim.jl:649
# ; Function _sum; {
# ; Location: reducedim.jl:650
# ; Function mapreduce; {
# ; Location: reducedim.jl:301
# ; Function #mapreduce#542; {
# ; Location: reducedim.jl:301
# ; Function _mapreduce_dim; {
# ; Location: reducedim.jl:305
# ; Function _mapreduce; {
# ; Location: reduce.jl:300
# ; Function Type; {
# ; Location: indices.jl:364
# ; Function axes; {
# ; Location: abstractarray.jl:83
# ; Function size; {
# ; Location: array.jl:155
#   %299 = load i64, i64 addrspace(11)* %103, align 8
# ;}
# ; Function map; {
# ; Location: tuple.jl:162
# ; Function Type; {
# ; Location: range.jl:298
# ; Function Type; {
# ; Location: range.jl:289
# ; Function max; {
# ; Location: promotion.jl:436
#   %300 = icmp sgt i64 %299, 0
# ;}}}}}}
# ; Location: reduce.jl:302
#   br i1 %300, label %L288, label %L327
#
# L288:                                             ; preds = %L279
# ; Location: reduce.jl:304
# ; Function ==; {
# ; Location: promotion.jl:425
#   %301 = icmp eq i64 %299, 1
# ;}
#   br i1 %301, label %L290, label %L294
#
# L290:                                             ; preds = %L288
# ; Location: reduce.jl:305
# ; Function getindex; {
# ; Location: array.jl:731
#   %302 = load double addrspace(13)*, double addrspace(13)* addrspace(11)* %135, align 8
#   %303 = load double, double addrspace(13)* %302, align 8
# ;}
# ; Location: reduce.jl:306
#   br label %L327
#
# L294:                                             ; preds = %L288
# ; Location: reduce.jl:307
# ; Function <; {
# ; Location: int.jl:49
#   %304 = icmp sgt i64 %299, 15
# ;}
#   br i1 %304, label %L313, label %L296
#
# L296:                                             ; preds = %L294
# ; Location: reduce.jl:309
# ; Function getindex; {
# ; Location: array.jl:731
#   %305 = load double addrspace(13)*, double addrspace(13)* addrspace(11)* %135, align 8
#   %306 = load double, double addrspace(13)* %305, align 8
# ;}
# ; Location: reduce.jl:310
# ; Function getindex; {
# ; Location: array.jl:731
#   %307 = getelementptr inbounds double, double addrspace(13)* %305, i64 1
#   %308 = load double, double addrspace(13)* %307, align 8
# ;}
# ; Location: reduce.jl:311
# ; Function add_sum; {
# ; Location: reduce.jl:21
# ; Function +; {
# ; Location: float.jl:395
#   %309 = fadd double %306, %308
# ;}}
# ; Location: reduce.jl:312
# ; Function <; {
# ; Location: int.jl:49
#   %310 = icmp sgt i64 %299, 2
# ;}
#   br i1 %310, label %L308.lr.ph, label %L327
#
# L308.lr.ph:                                       ; preds = %L296
#   br label %L308
#
# L308:                                             ; preds = %L308.lr.ph, %L308
#   %value_phi3582 = phi double [ %309, %L308.lr.ph ], [ %314, %L308 ]
#   %value_phi3481 = phi i64 [ 2, %L308.lr.ph ], [ %311, %L308 ]
# ; Location: reduce.jl:313
# ; Function +; {
# ; Location: int.jl:53
#   %311 = add nuw nsw i64 %value_phi3481, 1
# ;}
# ; Function getindex; {
# ; Location: array.jl:731
#   %312 = getelementptr inbounds double, double addrspace(13)* %305, i64 %value_phi3481
#   %313 = load double, double addrspace(13)* %312, align 8
# ;}
# ; Location: reduce.jl:314
# ; Function add_sum; {
# ; Location: reduce.jl:21
# ; Function +; {
# ; Location: float.jl:395
#   %314 = fadd double %value_phi3582, %313
# ;}}
# ; Location: reduce.jl:312
# ; Function <; {
# ; Location: int.jl:49
#   %315 = icmp ult i64 %311, %299
# ;}
#   br i1 %315, label %L308, label %L327
#
# L313:                                             ; preds = %L294
#   %316 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %gcframe, i32 3
#   store %jl_value_t addrspace(10)* %99, %jl_value_t addrspace(10)** %316
# ; Location: reduce.jl:318
# ; Function mapreduce_impl; {
# ; Location: reduce.jl:176
#   %317 = call double @julia_mapreduce_impl_37053(%jl_value_t addrspace(10)* %99, i64 1, i64 %299, i64 1024)
# ;}
#   br label %L327
#
# L327:                                             ; preds = %L308, %L296, %L290, %L313, %L279
#   %value_phi27 = phi double [ %303, %L290 ], [ %317, %L313 ], [ 0.000000e+00, %L279 ], [ %309, %L296 ], [ %314, %L308 ]
# ;}}}}}}}}
# ; Function setindex!; {
# ; Location: array.jl:771
#   %318 = load i64, i64 addrspace(11)* %56, align 8
#   %319 = icmp ult i64 %64, %318
#   br i1 %319, label %ib, label %oob
#
# L338:                                             ; preds = %idxend
# ;}
# ; Function iterate; {
# ; Location: range.jl:576
# ; Function +; {
# ; Location: int.jl:53
#   %320 = add nuw i64 %value_phi883, 1
# ;}}
# ; Function getindex; {
# ; Location: abstractarray.jl:913
# ; Function to_indices; {
# ; Location: indices.jl:265
# ; Function to_indices; {
# ; Location: indices.jl:269
# ; Function to_indices; {
# ; Location: multidimensional.jl:573
# ; Function uncolon; {
# ; Location: multidimensional.jl:578
# ; Function Type; {
# ; Location: indices.jl:286
# ; Function Type; {
# ; Location: indices.jl:286
#   store i64 %46, i64* %.sroa.066.0..sroa_idx, align 8
# ;}}}}}}
# ; Function _getindex; {
# ; Location: multidimensional.jl:588
# ; Function checkbounds; {
# ; Location: abstractarray.jl:457
#   br label %L63
#
# L339:                                             ; preds = %idxend, %L22
#   %.lcssa144181 = phi i64 [ %.lcssa144180, %L22 ], [ %46, %idxend ]
#   %value_phi3125.lcssa133179 = phi i64 [ %value_phi3125.lcssa133178, %L22 ], [ %value_phi3, %idxend ]
#   %.sroa.058.0.lcssa122164 = phi i64 [ %.sroa.058.0.lcssa122165, %L22 ], [ %.sroa.058.0, %idxend ]
#   %value_phi883.lcssa113156 = phi i64 [ %value_phi883.lcssa113157, %L22 ], [ %44, %idxend ]
#   %321 = phi i64 [ %60, %L22 ], [ %46, %idxend ]
# ;}}}
# ; Function iterate; {
# ; Location: range.jl:575
# ; Function ==; {
# ; Location: promotion.jl:425
#   %322 = icmp eq i64 %value_phi3, %35
# ;}}
#   br i1 %322, label %L350.loopexit, label %L349
#
# L349:                                             ; preds = %L339
# ; Function iterate; {
# ; Location: range.jl:576
# ; Function +; {
# ; Location: int.jl:53
#   %323 = add i64 %value_phi3, 1
# ;}}
#   br label %L22
#
# L350.loopexit:                                    ; preds = %L339
# ; Function getindex; {
# ; Location: abstractarray.jl:913
# ; Function _getindex; {
# ; Location: multidimensional.jl:588
#   store i64 %321, i64* %50, align 8
#   store i64 %value_phi883.lcssa113156, i64* %51, align 8
# ;}}
# ; Function materialize; {
# ; Location: broadcast.jl:724
# ; Function instantiate; {
# ; Location: broadcast.jl:266
# ; Function combine_axes; {
# ; Location: broadcast.jl:422
# ; Function broadcast_shape; {
# ; Location: broadcast.jl:427
# ; Function _bcs; {
# ; Location: broadcast.jl:433
#   store i64 %.sroa.058.0.lcssa122164, i64* %.sroa.055.0..sroa_idx56, align 8
# ;}}}}}
# ; Function getindex; {
# ; Location: abstractarray.jl:913
# ; Function _getindex; {
# ; Location: multidimensional.jl:588
#   store i64 %value_phi3125.lcssa133179, i64* %47, align 8
#   store i64 %.lcssa144181, i64* %48, align 8
# ;}}
# ; Location: In[1]:12
#   br label %L350
#
# L350:                                             ; preds = %L350.loopexit, %L7
#   %324 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %gcframe, i32 1
#   %325 = load %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %324
#   %326 = getelementptr %jl_value_t**, %jl_value_t*** %11, i32 0
#   %327 = bitcast %jl_value_t*** %326 to %jl_value_t addrspace(10)**
#   store %jl_value_t addrspace(10)* %325, %jl_value_t addrspace(10)** %327
#   ret %jl_value_t addrspace(10)* %41
#
# L351:                                             ; preds = %top
# ; Location: In[1]:5
# ; Function Type; {
# ; Location: boot.jl:292
#   %328 = bitcast %jl_value_t*** %11 to i8*
#   %329 = call noalias nonnull %jl_value_t addrspace(10)* @jl_gc_pool_alloc(i8* %328, i32 1376, i32 16) #2
#   %330 = bitcast %jl_value_t addrspace(10)* %329 to %jl_value_t addrspace(10)* addrspace(10)*
#   %331 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)* addrspace(10)* %330, i64 -1
#   store %jl_value_t addrspace(10)* addrspacecast (%jl_value_t* inttoptr (i64 4709106368 to %jl_value_t*) to %jl_value_t addrspace(10)*), %jl_value_t addrspace(10)* addrspace(10)* %331
#   %332 = bitcast %jl_value_t addrspace(10)* %329 to %jl_value_t addrspace(10)* addrspace(10)*
#   store %jl_value_t addrspace(10)* addrspacecast (%jl_value_t* inttoptr (i64 4606939664 to %jl_value_t*) to %jl_value_t addrspace(10)*), %jl_value_t addrspace(10)* addrspace(10)* %332, align 8
# ;}
#   %333 = addrspacecast %jl_value_t addrspace(10)* %329 to %jl_value_t addrspace(12)*
#   %334 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %gcframe, i32 2
#   store %jl_value_t addrspace(10)* %329, %jl_value_t addrspace(10)** %334
#   call void @jl_throw(%jl_value_t addrspace(12)* %333)
#   unreachable
#
# ib:                                               ; preds = %L327
# ; Location: In[1]:9
# ; Function setindex!; {
# ; Location: array.jl:771
#   %335 = add i64 %value_phi883, -1
#   %336 = load i64, i64 addrspace(11)* %58, align 8
#   %337 = icmp ult i64 %335, %336
#   br i1 %337, label %idxend, label %oob
#
# oob:                                              ; preds = %ib, %L327
#   %338 = alloca [2 x i64], align 8
#   %.sub = getelementptr inbounds [2 x i64], [2 x i64]* %338, i64 0, i64 0
#   store i64 %value_phi3, i64* %.sub, align 8
#   %339 = getelementptr inbounds [2 x i64], [2 x i64]* %338, i64 0, i64 1
#   store i64 %value_phi883, i64* %339, align 8
#   %340 = addrspacecast %jl_value_t addrspace(10)* %41 to %jl_value_t addrspace(12)*
#   call void @jl_bounds_error_ints(%jl_value_t addrspace(12)* %340, i64* nonnull %.sub, i64 2)
#   unreachable
#
# idxend:                                           ; preds = %ib
#   %341 = mul i64 %318, %335
#   %342 = add i64 %64, %341
#   %343 = load double addrspace(13)*, double addrspace(13)* addrspace(11)* %59, align 8
#   %344 = getelementptr inbounds double, double addrspace(13)* %343, i64 %342
#   store double %value_phi27, double addrspace(13)* %344, align 8
# ;}
# ; Function iterate; {
# ; Location: range.jl:575
# ; Function ==; {
# ; Location: promotion.jl:425
#   %345 = icmp eq i64 %value_phi883, %44
# ;}}
#   br i1 %345, label %L339, label %L338
# }

# %%
a = rand(10^7)
# Out:
# 10000000-element Array{Float64,1}:
#  0.06912063409191571
#  0.6605555484137551
#  0.7418959467920563
#  0.09866981297598443
#  0.3846042995236332
#  0.4548823803226969
#  0.8657346054689619
#  0.38989284863551
#  0.3399819051286541
#  0.8493922951810273
#  0.2614651972749511
#  0.042737990127250214
#  0.5206661891205255
#  ⋮
#  0.8637683335042361
#  0.8998884487693246
#  0.6547660649215932
#  0.3723075139295797
#  0.39007897172249306
#  0.5414786100923696
#  0.49650684863517536
#  0.9336377932892619
#  0.14889720227563075
#  0.3177230443052339
#  0.7058313775112555
#  0.6169634051674571

# %%
sum(a)/length(a)
# Out:
# 0.5000879670603202

# %%
using BenchmarkTools, Libdl

# %%
C_code = """
#include <stddef.h>
double c_sum(size_t n, double *X) {
    double s = 0.0;
    for (size_t i = 0; i < n; ++i) {
        s += X[i];
    }
    return s;
}
"""

const Clib = tempname()   # make a temporary file


# compile to a shared library by piping C_code to gcc
# (works only if you have gcc installed):

open(`gcc -fPIC -O3 -msse3 -xc -shared -o $(Clib * "." * Libdl.dlext) -`, "w") do f
    print(f, C_code) 
end

# define a Julia function that calls the C function:
c_sum(X::Array{Float64}) = ccall(("c_sum", Clib), Float64, (Csize_t, Ptr{Float64}), length(X), X)
# Out:
# c_sum (generic function with 1 method)

# %%
a = rand(10^7)
# Out:
# 10000000-element Array{Float64,1}:
#  0.6987951608178609
#  0.19972342860567838
#  0.6743865986637485
#  0.4936267005960362
#  0.4020847296684331
#  0.7999804239881785
#  0.5565583207999754
#  0.19786558737490445
#  0.11525843077482323
#  0.8936256284890614
#  0.9743632813264052
#  0.42033237026053616
#  0.28865281913547225
#  ⋮
#  0.5016295249786886
#  0.7962582992993255
#  0.8043036926836882
#  0.25256037625339034
#  0.5039177287704752
#  0.8250510920344358
#  0.6887259603146056
#  0.7992443790703772
#  0.2669179786824609
#  0.06717141232282797
#  0.1998934628722231
#  0.3044968108082102

# %%
c_sum(a)
# Out:
# 4.998491923572921e6

# %%
b = rand(10)
# Out:
# 10-element Array{Float64,1}:
#  0.9613552369221878
#  0.2541051629450206
#  0.5779491860874129
#  0.9772257090978973
#  0.6669808293028874
#  0.9694098903806068
#  0.37675827430129716
#  0.4182268617804865
#  0.8712572646725538
#  0.5271436626312807

# %%
run(`gfortran -fPIC -O3 -shared sumvec.F90 -o libsumvec.so`)
# Out:
# Process(`gfortran -fPIC -O3 -shared sumvec.F90 -o libsumvec.so`, ProcessExited(0))

# %%
function sumvec(x::Vector{Float64})
    outsum = Ref(0.0)
    N = Ref(length(x))
    ccall((:sumvec_, "./libsumvec.so"), Nothing,
        (Ptr{Float64}, Ref{Int64}, Ref{Float64}),
        x, N, outsum)
    return outsum[]
end
sumvec([1.0, 2.0])
# Out:
# 3.0

# %%
X = rand(10^7)
# Out:
# 10000000-element Array{Float64,1}:
#  0.7913418556781557
#  0.17971002910667355
#  0.5872893557991585
#  0.4530415659964364
#  0.9100096911726485
#  0.5413760557393317
#  0.46332971004719736
#  0.4237333685868405
#  0.3184429005866909
#  0.5139495343006764
#  0.9854312778595864
#  0.4137041184735246
#  0.1851021963791808
#  ⋮
#  0.10441693410961173
#  0.824145547867482
#  0.8090241638723381
#  0.6463966356164685
#  0.5198541072725753
#  0.009030983487056776
#  0.5028057074176842
#  0.7776178342988742
#  0.5788767808122302
#  0.25317445547426765
#  0.8826012704344803
#  0.8700314536549074
